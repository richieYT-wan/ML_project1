# %%
# Useful starting lines
# %timeit
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from implementations import *
from proj1_helpers import *
from preprocessing import *

# %load_ext autoreload
# %autoreload 2
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv'
y, tx_train, ids = load_csv_data(DATA_TRAIN_PATH)

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
import numpy as np
def load_csv_data(data_path, sub_sample=False):
    """Loads data and returns y (class labels), tX (features) and ids (event ids)"""
    y = np.genfromtxt(data_path, delimiter=",", skip_header=1, dtype=str, usecols=1)
    x = np.genfromtxt(data_path, delimiter=",", skip_header=1)
    ids = x[:, 0].astype(np.int)
    input_data = x[:, 2:]

    # convert class labels from strings to binary (-1,1)
    yb = np.ones(len(y))
    yb[np.where(y=='b')] = -1
    
    # sub-sample
    if sub_sample:
        yb = yb[::50]
        input_data = input_data[::50]
        ids = ids[::50]

    return yb, input_data, ids
DATA_TRAIN_PATH = '../data/train.csv'

y, tx_train, ids = load_csv_data(DATA_TRAIN_PATH)

# %%
tx_1 = tx_train[0:50]
tx_2 = tx_train[0:50]

# %%
tx_1[3,5:7]
tx_2[3,5:7]
# Out:
# array([-999., -999.])

# %%
tx_1 = np.where(tx_1 == -999, np.nan, tx_1)s

tx_2[tx_2==-999]= np.nan

print(tx_1[3,5:7]
,tx_2[3,5:7])
# Out:
# [nan nan] [nan nan]

# %%
np.nanmean(tx_1,axis=0).shape
# Out:
# (30,)

# %%
def convert_label(y):
    """converts the labels into 0 or 1 for log reg"""
    #copy to prevent unwanted inplace value assignment
    bin_y = y.copy()
    #using fancy numpy indexing
    bin_y[bin_y==-1]=0
    return bin_y

# %%
#number of jet index is 22, we seperate by number of jet.
def separate_per_numjet(y,x_train):
    print(np.count_nonzero(x_train[:,22] == 0))
    
separate_per_numjet(y,tx_train)
    (A CONTINUER)

# %% [markdown]
# ## Previsualization

# %%
tx_train[:,0]

# %%
#Visualize the datas of each feature
def visualize_alone(tx_train):
    
    #import the name of the feature from the train.csv
    with open(DATA_TRAIN_PATH) as tr_csv:
        reader = csv.reader(tr_csv)
        header = next(reader)
        
    #plot of the feature (without printing the ID (index 0), and prediction(index1))
    fig, axes = plt.subplots(14,2,figsize=(40,40),sharex =True)
    ax = axes.ravel()
    for ind_feat in range(len(tx_train[0])-1):
        ax[ind_feat].plot(tx_train[:,ind_feat+2])
        ax[ind_feat].set_title(header[ind_feat+2])

# %%
visualize_alone(tx_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-1dbd43a39977> in <module>
# ----> 1 visualize_alone(tx_train)
#
# <ipython-input-6-c6b805cbf3c1> in visualize_alone(tx_train)
#      11     ax = axes.ravel()
#      12     for ind_feat in range(len(tx_train[0])-1):
# ---> 13         ax[ind_feat].plot(tx_train[:,ind_feat+2])
#      14         ax[ind_feat].set_title(header[ind_feat+2])
#
# IndexError: index 28 is out of bounds for axis 0 with size 28

# %%
def visualize_compare(tx_train):

# %% [markdown]
# ## Do your thing crazy machine learning thing here :) ...

# %%
y.shape

# %%
n_samples = 30000
#Sampling a small subset of the dataset,
y_normal, temp = sample_data(y,tx_train,n_samples)
tx_normal, _, _ = standardize(temp)

y_normal = convert_label(y_normal)
# standardizing input
y_sampled, tx_sampled = sample_data(y,tx_train,n_samples)
y_sampled = convert_label(y_sampled)
#confirm unbiased
print(tx_sampled[0:3,0:5])
#Init weight
w0 = np.random.randn(tx_sampled.shape[1],1)
print(w0.shape)

# %%
#adding bias
tx_sampled_bias = np.c_[np.ones((y_sampled.shape[0], 1)), tx_sampled]
tx_normal_bias = np.c_[np.ones((y_normal.shape[0], 1)), tx_normal]
w0_bias = np.random.randn(tx_sampled_bias.shape[1],1)
#init values for iterations
n_iters = 1750
gamma = 1e-7

# %%
#4 OUTPUTS : 
#1) normal input, no bias
w_log, loss, losses = logistic_regression(y_sampled,
                                          tx_sampled,w0,
                                          n_iters, gamma)
#2) normalized input, no bias
w_logstd, loss_std, losses_std = logistic_regression(y_normal,
                                                    tx_normal,
                                                    w0, n_iters,
                                                    gamma)
#3) normal input, with bias
w_log_b, loss_b, losses_b = logistic_regression(y_sampled,
                                          tx_sampled_bias,w0_bias,
                                          n_iters, gamma)

#4) normalized input, with bias
w_logstd_b, loss_std_b, losses_std_b = logistic_regression(y_normal,
                                                    tx_normal_bias,
                                                    w0_bias, n_iters,
                                                    gamma)

# %%
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex =True)
ax = axes.ravel()
ax[0].plot(losses)
ax[0].set_title("loss, un_normalized data")
ax[1].plot(losses_std)
ax[1].set_title("losses, normalized data")
ax[0].set_xlabel("ITERATIONS")
ax[1].set_ylabel("ITERATIONS")

ax[2].plot(losses_b)
ax[2].set_title("loss, un_normalized data BIASED")
ax[3].plot(losses_std_b)
ax[3].set_title("losses, normalized data BIASED")
ax[2].set_xlabel("ITERATIONS")
ax[3].set_xlabel("ITERATIONS")
fig.suptitle("logistic reg losses, for {} samples,gamma = {}".format(n_samples,gamma))
# Out:
# Text(0.5, 0.98, 'logistic reg losses, for 50000 samples,gamma = 1e-07')

# %%
lambda_= 7e-3
#4 OUTPUTS : 
#1) normal input, no bias
w_logR, lossR, lossesR = reg_logistic_regression(y_sampled,lambda_,
                                          tx_sampled,w0,
                                          n_iters, gamma)
#2) normalized input, no bias
w_logstdR, loss_stdR, losses_stdR = reg_logistic_regression(y_normal,lambda_,
                                                    tx_normal,
                                                    w0, n_iters,
                                                    gamma)
#3) normal input, with bias
w_log_bR, loss_bR, losses_bR = reg_logistic_regression(y_sampled,lambda_,
                                          tx_sampled_bias,w0_bias,
                                          n_iters, gamma)

#4) normalized input, with bias
w_logstd_bR, loss_std_bR, losses_std_bR = reg_logistic_regression(y_normal,lambda_,
                                                    tx_normal_bias,
                                                    w0_bias, n_iters,
                                                    gamma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-c064102018fb> in <module>()
#       4 w_logR, lossR, lossesR = reg_logistic_regression(y_sampled,lambda_,
#       5                                           tx_sampled,w0,
# ----> 6                                           n_iters, gamma)
#       7 #2) normalized input, no bias
#       8 w_logstdR, loss_stdR, losses_stdR = reg_logistic_regression(y_normal,lambda_,
#
# C:\Users\richi\Documents\EPFL\Master\MA3_2\Machine Learning\practicals\projects\LOCAL_project1\scripts\implementations.py in reg_logistic_regression(y, tx, lambda_, initial_w, max_iters, gamma)
#     100
#     101     for i in range(max_iters):
# --> 102         gradient = compute_log_gradient(y, tx, w) + 2*lambda_* w
#     103         w = w - gamma*gradient
#     104     loss = compute_logloss(y, tx, w) + 0.5*lambda_*np.squeeze(w.T.dot(w))
#
# C:\Users\richi\Documents\EPFL\Master\MA3_2\Machine Learning\practicals\projects\LOCAL_project1\scripts\costs.py in compute_log_gradient(y, tx, w)
#      32     """Computes the gradient for logistic regression
#      33     """
# ---> 34     sig = sigmoid(tx.dot(w))
#      35     #reshaping, we had broadcasting issues.
#      36     grad = tx.T.dot(sig-(y.reshape(sig.shape)))
#
# AttributeError: 'float' object has no attribute 'dot'

# %% [markdown]
# ## Generate predictions and save ouput in csv format for submission:

# %%
DATA_TEST_PATH = '../data/test.csv' # TODO: download test data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
#pre processing
tX_test, _, _ = standardize(tX_test)
#adding bias for biased input
tX_test_bias = np.c_[np.ones((tX_test.shape[0],1)),tX_test]

# %%
OUTPUT_PATH = '../output/' # TODO: fill in desired name of output file for submission
y_pred = predict_labels_log(w_logstd, tX_test)
y_pred_bias = predict_labels_log(w_logstd_b, tX_test_bias)

create_csv_submission(ids_test, y_pred, OUTPUT_PATH+"logistic.csv")
create_csv_submission(ids_test, y_pred, OUTPUT_PATH+"logistic_bias.csv")
