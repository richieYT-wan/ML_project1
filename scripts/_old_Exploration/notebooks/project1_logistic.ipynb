# %%
# Useful starting lines
# %timeit
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from implementations import *
from proj1_helpers import *
from preprocessing import *

# %load_ext autoreload
# %autoreload 2
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv'
y, tx_train, ids = load_csv_data(DATA_TRAIN_PATH)

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
def convert_label(y):
    """converts the labels into 0 or 1 for log reg"""
    #copy to prevent unwanted inplace value assignment
    bin_y = y.copy()
    #using fancy numpy indexing
    bin_y[bin_y==-1]=0
    return bin_y

# %% [markdown]
# ## Do your thing crazy machine learning thing here :) ...

# %%
n_samples = 30000
#Sampling a small subset of the dataset,
y_normal, temp = sample_data(y,tx_train,n_samples)
tx_normal = standardize(temp)

y_normal = convert_label(y_normal)
# standardizing input
y_sampled, tx_sampled = sample_data(y,tx_train,n_samples)
y_sampled = convert_label(y_sampled)
#confirm unbiased
print(tx_sampled[0:3,0:5])
#Init weight
w0 = np.random.randn(tx_sampled.shape[1],1)
print(w0.shape)
# Out:
# [[ 1.25712e+02  3.85570e+01  8.51410e+01  1.44500e+00 -9.99000e+02]
#  [ 1.48082e+02  3.16190e+01  1.02263e+02  3.05500e+00 -9.99000e+02]
#  [ 7.47330e+01  1.68200e+00  4.36410e+01  1.89361e+02  4.20000e-01]]
# (30, 1)

# %%
#adding bias
tx_sampled_bias = np.c_[np.ones((y_sampled.shape[0], 1)), tx_sampled]
tx_normal_bias = np.c_[np.ones((y_normal.shape[0], 1)), tx_normal]
w0_bias = np.random.randn(tx_sampled_bias.shape[1],1)
#init values for iterations
n_iters = 1750
gamma = 1e-5

# %%
#4 OUTPUTS : 
#1) normal input, no bias
w_log, loss, losses = logistic_regression(y_sampled,
                                          tx_sampled,w0,
                                          n_iters, gamma)
#2) normalized input, no bias
w_logstd, loss_std, losses_std = logistic_regression(y_normal,
                                                    tx_normal,
                                                    w0, n_iters,
                                                    gamma)
##3) normal input, with bias
#w_log_b, loss_b, losses_b = logistic_regression(y_sampled,
#                                          tx_sampled_bias,w0_bias,
#                                          n_iters, gamma)
#
##4) normalized input, with bias
#w_logstd_b, loss_std_b, losses_std_b = logistic_regression(y_normal,
#                                                    tx_normal_bias,
#                                                    w0_bias, n_iters,
#                                                    gamma)

# %%
tmp = np.empty((5,10,n_iters))
tmp[0,2,:]=losses
tmp[1,5,:]=losses_std
xd = losses_std[0:1500]

# %%
tmp[0,7,:]=xd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1b2d26873bca> in <module>()
# ----> 1 tmp[0,7,:]=xd
#
# ValueError: cannot copy sequence with size 1500 to array axis with dimension 1750

# %%
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex =True)
ax = axes.ravel()
ax[0].plot(losses)
ax[0].set_title("loss, un_normalized data")
ax[1].plot(losses_std)
ax[1].set_title("losses, normalized data")
ax[0].set_xlabel("ITERATIONS")
ax[1].set_xlabel("ITERATIONS")

ax[2].plot(losses_b)
ax[2].set_title("loss, un_normalized data BIASED")
ax[3].plot(losses_std_b)
ax[3].set_title("losses, normalized data BIASED")
ax[2].set_xlabel("ITERATIONS")
ax[3].set_xlabel("ITERATIONS")
fig.suptitle("logistic reg losses, for {} samples,gamma = {}".format(n_samples,gamma))
# Out:
# Text(0.5, 0.98, 'logistic reg losses, for 30000 samples,gamma = 1e-05')

# %%
lambda_= 5e-4
gamma = 1e-6
#4 REGULARIZED LOG REG
#1) normal input, no bias
w_logR, lossR, lossesR = reg_logistic_regression(y_sampled,
                                          tx_sampled,lambda_,w0,
                                          n_iters, gamma)
#2) normalized input, no bias
w_logstdR, loss_stdR, losses_stdR = reg_logistic_regression(y_normal,
                                                    tx_normal,lambda_,
                                                    w0, n_iters,
                                                    gamma)
#3) normal input, with bias
w_log_bR, loss_bR, losses_bR = reg_logistic_regression(y_sampled,
                                          tx_sampled_bias,lambda_,w0_bias,
                                          n_iters, gamma)

#4) normalized input, with bias
w_logstd_bR, loss_std_bR, losses_std_bR = reg_logistic_regression(y_normal,
                                                    tx_normal_bias,lambda_,
                                                    w0_bias, n_iters,
                                                    gamma)

# %%
fig, axes = plt.subplots(2,2,figsize=(10,8),sharex =True)
ax = axes.ravel()
ax[0].plot(lossesR)
ax[0].set_title("loss, un_normalized data")
ax[1].plot(losses_stdR)
ax[1].set_title("losses, normalized data")
ax[0].set_xlabel("ITERATIONS")
ax[1].set_xlabel("ITERATIONS")

ax[2].plot(losses_bR)
ax[2].set_title("loss, un_normalized data BIASED")
ax[3].plot(losses_std_bR)
ax[3].set_title("losses, normalized data BIASED")
ax[2].set_xlabel("ITERATIONS")
ax[3].set_xlabel("ITERATIONS")
fig.suptitle("Regularized logistic reg losses, for {} samples,gamma = {}, lambda = {}".format(n_samples,gamma,lambda_))
# Out:
# Text(0.5, 0.98, 'Regularized logistic reg losses, for 30000 samples,gamma = 1e-06, lambda = 0.0005')

# %% [markdown]
# ## Generate predictions and save ouput in csv format for submission:

# %%
DATA_TEST_PATH = '../data/test.csv' # TODO: download test data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
#pre processing
tX_test, _, _ = standardize(tX_test)
#adding bias for biased input
tX_test_bias = np.c_[np.ones((tX_test.shape[0],1)),tX_test]
tX_test.shape, tX_test_bias.shape
# Out:
# ((568238, 30), (568238, 31))

# %%
OUTPUT_PATH = '../output/' # TODO: fill in desired name of output file for submission
y_pred = predict_labels_log(w_logstd, tX_test)
y_pred_bias = predict_labels_log(w_logstd_b, tX_test_bias)
y_reg = predict_labels_log(w_logstdR, tX_test)
create_csv_submission(ids_test, y_pred, OUTPUT_PATH+"logistic.csv")
create_csv_submission(ids_test, y_pred_bias, OUTPUT_PATH+"logistic_bias.csv")
create_csv_submission(ids_test, y_pred, OUTPUT_PATH+"reguLog.csv")

# %%
print(y_reg)
# Out:
# [-1. -1. -1. ... -1. -1. -1.]
